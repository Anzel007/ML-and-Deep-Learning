# %% [markdown]
# Relu Sigmoid
# 10 ota class ko esko eti esko eto bhanxa duita display garna man laye duita gara natra tinta duitai opton deko simple sinple kura deko ho
# laa padhdim hai ta hamro regression gardim hamis sanga kkk error hunxa evaluate garamy ko value 1 halda yo hatxa hai ... blkacknbox ke narakhni hai
# hamro real loss fxn yo ho y zero aaye yo one aayo bhane yo
#
#
# hamle y predict hanni ho yedi hamro original y zero raixa bhane k garni ani 0 raixa bhane k ho
#
# mean absp;ute error?> loss kati aayo summation 12 kati aay oy-h1ajsdoi square so yo a nai ho hai haina ra yo ni feature yo ni fearute kura tei nai ho best fit nikalni hnai ho tessaile sakkyo hai ta sajilo xa janna esma eiuta matra minina hunxa dherai aauni chances hudaina conver sion ni fast xa euta matra minima banxa ki local ki global yo //
# yo absolute hai ///
# yo bhaye paxi yo plus hunxa yo bhaye yo plus hunxa duita madhya jun sukai choose garda hunxa tyo outliers ko lagi ho euta ihterwise yo use garni
# yo ta regression ko kura bhp hai aba hamro loss jun hunxa tellai chai herni kam garni Cross EWntropy haiii
#
# code copy agryo tya mialyo tara yo kura chutira hunxa...
#
# binary ko thauu ma category lekhira hunxa//
# logistic regression le dinxa hai yo hi poredition y hat yo y true yo y prediction.. log one minus y
# derieved from logistic regression
# classification y equal to zero

# %% [markdown]
# ab f1 f2 f3 hami sanga features bhayo ... 100=good bad--sth sth ...
# yo ho outpuit encoding
# data esot xa hai bhanesi yo formula lai change agrna paryo tmi harule 100 ma change garam ...]
#
# laa yo kura ni gardai garamla aru kura tei ho yo loss fxn ho ..
# estai ho
# bujhyo ni haii ho bhane 1 natra zero haii
# softmax activation
# laa yo math ho olnine ni bujhdai gar ahaii
# laa ocnc,usion banairakha kaa final lahyr ma softmac for multi layer
# yesko loss financial..,

# %% [markdown]
# <h1>ACTIVATION FUNCTIONS</h1>
#
# ---
# sigmoid function
#
# ---
# tanh
#
# ---
#
# ReLU----------- Rectified Linear Unit
#
# ---
#
# Leaky ReLU ---
#
#
# ---
#
#
# ELU-----------Exponential Linear Units
#
#
# ---
#
#
# Softmax
#
# ---
#
# PReLU------Parameyric ReLU
#
# ---
#
# Swish ---- (A Self_gated )function
