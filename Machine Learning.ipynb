# %% [markdown]
# Types of machine learning
#
#
# 1.   supervised: tack driven
# 2.   unsupervised: data driven
# 3.   Reinforcement: rewards driven

# %% [markdown]
# Supervised
#
#
# *   linear regression
# *   KNN
# *  Decision Tree
# * logistic reg

# %% [markdown]
# Unsupervised
#
#
# 1.   K means
# 2.   DB scan
# 3. K near neighbour clustering
# 4. PCA
# 5. LDA

# %% [markdown]
# 1. Classification = classified on the fixed parameters
#
#
#
#
# 2. Regression = The final classification values can be random

# %% [markdown]
# ANDREW NG - AI  GURU coursera

# %% [markdown]
# 🐜

# %% [markdown]
# <H1>PROBABILITY<H1>

# %% [markdown]
# MUTUALLY EXPLUSIVE -- MUHTIPLE EVENTS CANT HAPPEN AT THE SAME TIME.------------ EG- DICE ROLL,COIN TOSS
# NON MUTUALLY EXCLUSIVE--- MULTIPLE EVENTS CAN HAPPEN AT THE SAME TIME CARDS DECK-- A CARD CAN BE QUEEN OR DIAMOND AT THE SAME TIME

# %% [markdown]
# <h3> Multiplication rule</h3>

# %% [markdown]
# permutation =n!/(n-r)!
#
# Combination=n!/[r!*(n-r)!]

# %% [markdown]
# <h3> Bayes theorem </h3>
#
# p(b/a)=[p(b)*p(a/b)]/p(a)

# %% [markdown]
# <h3> Naive Bayes </h3>
# <i>this does classification </i>

# %% [markdown]
# <h2>***************** Unsupervised Data**************************** </h2>

# %% [markdown]
# <h3> KNN Algorithm</h3>
#
#
# 1.   classification-- voting of nearest neighbour and new element belongs toi the winnign class
# 2.   Regression--- the new element is the average value of the nearest neighbours

# %% [markdown]
# <h2> Unsupervisedd ML </h2>
# <h3> Clustering</h3>

# %% [markdown]
# <h3> 1. K Means Clustering</h3>
# - grouping data into groups(eg 2)
# - now centroid(central value) is choosed for the clusters
# - the average dist is calcualted from centroid to each points in the cluster
# - the average value must match the centroid value
# -if it doesnt match then the calcualted average value is taken as new centroid
# -then average distance is calculated similary
# - now now the calculated average value and the centroid is compared .....
# then the process is repeated

# %% [markdown]
# <h3> 2. Elbow method clustering </h3>
