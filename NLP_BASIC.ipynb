# %% [markdown]
# BASIC NLP
# ---

# %%
import nltk
#nltk.download()

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
#introduction
text= " It is a sentence that we use for an example, This is comma :This is colon  "
text= text.lower()
print(text)
# Out:
#  it is a sentence that we use for an example, this is comma :this is colon

# %%
#removing punctuation
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
text_p ="".join([char for char in text if char not in string.punctuation])
print(text_p)
# Out:
#  it is a sentence that we use for an example this is comma this is colon

# %%
#tokenizing------------- splitting the 
from nltk import word_tokenize
words= word_tokenize(text_p)
print(words)
# Out:
# ['it', 'is', 'a', 'sentence', 'that', 'we', 'use', 'for', 'an', 'example', 'this', 'is', 'comma', 'this', 'is', 'colon']

# %%
#removing StopWords
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
filtered_words = [word for word in words if word not in stop_words]
print(filtered_words)
# Out:
# ['sentence', 'use', 'example', 'comma', 'colon']

# %%
#STEMMING
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
stemmed = [porter.stem(word) for word in filtered_words]
print(stemmed)
# Out:
# ['sentenc', 'use', 'exampl', 'comma', 'colon']

# %%
#part of speech ----------- grammar
from nltk import pos_tag
pos= pos_tag(filtered_words)
print(pos)
# Out:
# [('sentence', 'NN'), ('use', 'NN'), ('example', 'NN'), ('comma', 'NN'), ('colon', 'NN')]

# %% [markdown]
# USE THIS PROCESS AS A WHOLE IN A SINGLE FUNCTION
# ---
# ---

# %%
import nltk
import string
from nltk import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %%
def preprocess(text):
  text = text.lower()
  words= word_tokenize(text_p)

  stop_words= stopwords.words('english')
  filtered_words=[word for word in words if word not in stop_words]
  porter = PorterStemmer()
  stemmed= [porter.stem(word) for word in filtered_words]
  pos= pos_tag(filtered_words)

  return words, filtered_words, stemmed, pos

# %%
txt="It is a truth university acknowledged, that a single man in position is a dictatorship, : so this can be affecting the envirinment of the university."

# %%
preprocess(txt)
# Out:
# (['it',
#   'is',
#   'a',
#   'sentence',
#   'that',
#   'we',
#   'use',
#   'for',
#   'an',
#   'example',
#   'this',
#   'is',
#   'comma',
#   'this',
#   'is',
#   'colon'],
#  ['sentence', 'use', 'example', 'comma', 'colon'],
#  ['sentenc', 'use', 'exampl', 'comma', 'colon'],
#  [('sentence', 'NN'),
#   ('use', 'NN'),
#   ('example', 'NN'),
#   ('comma', 'NN'),
#   ('colon', 'NN')])
